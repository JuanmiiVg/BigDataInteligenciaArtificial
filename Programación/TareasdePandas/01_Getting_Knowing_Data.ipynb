# %% [markdown]
# # Ejercicios: Getting & Knowing Your Data
#
# ### Objetivos de aprendizaje:
# - Importar datos desde archivos y URLs
# - Explorar la estructura básica de un DataFrame
# - Usar métodos fundamentales: head(), tail(), shape, info(), describe()
# - Entender tipos de datos y conversiones
# - Realizar cálculos básicos sobre columnas
#
# ### Dataset: Chipotle Orders
# Vamos a trabajar con datos de pedidos del restaurante Chipotle.

# %% [markdown]
# ### Ejercicio 1: Importar las librerías necesarias
# Importa pandas y numpy

# %%
# Pista: import pandas as pd, import numpy as np
import pandas as pd
import numpy as np

# %%
# Test: Verificar que pandas está importado
assert 'pd' in dir(), "Pandas no está importado como 'pd'"
print("✓ Test pasado: Librerías importadas correctamente")
# Out:
# ✓ Test pasado: Librerías importadas correctamente

# %% [markdown]
# ### Ejercicio 2: Cargar el dataset
# Carga el dataset de Chipotle desde la URL proporcionada y asígnalo a una variable llamada `chipo`.
#
# **URL:** https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv

# %%
# Pista: usa pd.read_csv() con el parámetro sep='\t' para archivos TSV
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

chipo = pd.read_csv(url, sep="\t")

# %%
# Test: Verificar que el dataset se cargó correctamente
assert 'chipo' in dir(), "Variable 'chipo' no existe"
assert chipo.shape[0] > 0, "El DataFrame está vacío"
print(f"✓ Test pasado: Dataset cargado con {chipo.shape[0]} filas")
# Out:
# ✓ Test pasado: Dataset cargado con 4622 filas

# %% [markdown]
# ### Ejercicio 3: Visualizar las primeras 10 filas
# Muestra las primeras 10 entradas del dataset

# %%
# Pista: usa el método .head() con un parámetro
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# Test: No hay test automático para visualización
print("✓ Revisa visualmente que se muestran 10 filas")
# Out:
# ✓ Revisa visualmente que se muestran 10 filas

# %% [markdown]
# ### Ejercicio 4: Número de observaciones
# ¿Cuántas observaciones (filas) tiene el dataset?

# %%
# Pista: usa .shape[0] o len()
num_observaciones = chipo.shape[0]

# %%
# Test: Verificar el número de observaciones
assert num_observaciones == 4622, f"Esperado 4622, obtenido {num_observaciones}"
print(f"✓ Test pasado: {num_observaciones} observaciones")
# Out:
# ✓ Test pasado: 4622 observaciones

# %% [markdown]
# ### Ejercicio 5: Número de columnas
# ¿Cuántas columnas tiene el dataset?

# %%
# Pista: usa .shape[1] o len(chipo.columns)
num_columnas = chipo.shape[1]

# %%
# Test: Verificar el número de columnas
assert num_columnas == 5, f"Esperado 5, obtenido {num_columnas}"
print(f"✓ Test pasado: {num_columnas} columnas")
# Out:
# ✓ Test pasado: 5 columnas

# %% [markdown]
# ### Ejercicio 6: Nombres de las columnas
# Imprime los nombres de todas las columnas

# %%
# Pista: usa el atributo .columns
nombres_columnas = list(chipo.columns)

# %%
# Test: Verificar nombres de columnas
columnas_esperadas = ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']
assert list(chipo.columns) == columnas_esperadas, "Columnas incorrectas"
print("✓ Test pasado: Columnas correctas")
# Out:
# ✓ Test pasado: Columnas correctas

# %% [markdown]
# ### Ejercicio 7: Información del índice
# ¿Cómo está indexado el dataset?

# %%
# Pista: usa el atributo .index
indice = chipo.index

# %%
# Test: Verificar que el índice es RangeIndex
assert isinstance(chipo.index, pd.RangeIndex), "Índice no es RangeIndex"
print("✓ Test pasado: Índice es RangeIndex (0, 1, 2, ...)")
# Out:
# ✓ Test pasado: Índice es RangeIndex (0, 1, 2, ...)

# %% [markdown]
# ### Ejercicio 8: Información general del DataFrame
# Usa el método info() para ver información general sobre el dataset

# %%
# Pista: simplemente llama al método .info()
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
# Test: No hay test automático
print("✓ Revisa la información mostrada")
# Out:
# ✓ Revisa la información mostrada

# %% [markdown]
# ### Ejercicio 9: Tipos de datos
# ¿Qué tipo de dato tiene la columna 'item_price'?

# %%
# Pista: usa .dtype o .dtypes
tipo_price = chipo['item_price'].dtype

# %%
# Test: Verificar tipo de dato
assert chipo['item_price'].dtype == 'object', "El tipo debería ser 'object' (string)"
print(f"✓ Test pasado: item_price es de tipo {chipo['item_price'].dtype}")
# Out:
# ✓ Test pasado: item_price es de tipo object

# %% [markdown]
# ### Ejercicio 10: Total de items pedidos
# ¿Cuántos items fueron pedidos en total?

# %%
# Pista: suma la columna 'quantity'
total_items = chipo['quantity'].sum()

# %%
# Test: Verificar total
assert total_items == 4972, f"Esperado 4972, obtenido {total_items}"
print(f"✓ Test pasado: {total_items} items pedidos en total")
# Out:
# ✓ Test pasado: 4972 items pedidos en total

# %% [markdown]
# ### Ejercicio 11: Convertir precio a float
# La columna 'item_price' es un string (object). Conviértela a float.
#
# Primero, observa cómo están los valores (tienen el símbolo $ y espacios)

# %%
# Pista: Crea una función lambda que elimine el símbolo $ y convierta a float
# Usa .apply() para aplicarla a toda la columna
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x.replace('$', '').strip()))

# %%
# Test: Verificar conversión
assert chipo['item_price'].dtype in ['float64', 'float32'], f"Tipo incorrecto: {chipo['item_price'].dtype}"
print(f"✓ Test pasado: item_price convertido a {chipo['item_price'].dtype}")
# Out:
# ✓ Test pasado: item_price convertido a float64

# %% [markdown]
# ### Ejercicio 12: Revenue total
# ¿Cuál fue el ingreso total (revenue) del periodo?

# %%
# Pista: multiplica quantity * item_price y suma todo
revenue = (chipo['quantity'] * chipo['item_price']).sum()

# %%
# Test: Verificar revenue (aproximado)
assert 39000 < revenue < 40000, f"Revenue esperado ~39237, obtenido {revenue}"
print(f"✓ Test pasado: Revenue total = ${revenue:,.2f}")
# Out:
# ✓ Test pasado: Revenue total = $39,237.02

# %% [markdown]
# ### Ejercicio 13: Número de órdenes
# ¿Cuántas órdenes diferentes se realizaron?

# %%
# Pista: cuenta los valores únicos de 'order_id'
num_ordenes = chipo['order_id'].nunique()

# %%
# Test: Verificar número de órdenes
assert num_ordenes == 1834, f"Esperado 1834, obtenido {num_ordenes}"
print(f"✓ Test pasado: {num_ordenes} órdenes realizadas")
# Out:
# ✓ Test pasado: 1834 órdenes realizadas

# %% [markdown]
# ### Ejercicio 14: Revenue promedio por orden
# ¿Cuál es el ingreso promedio por orden?

# %%
# Pista: agrupa por order_id, suma el revenue de cada orden, y calcula el promedio
revenue_promedio = (chipo['quantity'] * chipo['item_price']).groupby(chipo['order_id']).sum().mean()

# %%
# Test: Verificar revenue promedio
assert 18 < revenue_promedio < 22, f"Revenue promedio esperado ~21, obtenido {revenue_promedio}"
print(f"✓ Test pasado: Revenue promedio por orden = ${revenue_promedio:.2f}")
# Out:
# ✓ Test pasado: Revenue promedio por orden = $21.39

# %% [markdown]
# ### Ejercicio 15: Items diferentes vendidos
# ¿Cuántos items diferentes se venden?

# %%
# Pista: cuenta los valores únicos de 'item_name'
items_unicos = chipo['item_name'].nunique()

# %%
# Test: Verificar items únicos
assert items_unicos == 50, f"Esperado 50, obtenido {items_unicos}"
print(f"✓ Test pasado: {items_unicos} items diferentes")
# Out:
# ✓ Test pasado: 50 items diferentes

# %% [markdown]
# ## ¡Ejercicios completados! 🎉
#
# Has aprendido a:
# - ✓ Cargar datos desde archivos y URLs
# - ✓ Explorar la estructura de un DataFrame
# - ✓ Trabajar con diferentes tipos de datos
# - ✓ Realizar cálculos y agregaciones básicas
