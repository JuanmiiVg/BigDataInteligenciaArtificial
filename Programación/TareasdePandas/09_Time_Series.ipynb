# %% [markdown]
# # Time Series
#
# ### Dataset: Apple Stock

# %% [markdown]
# ### Ejercicio 1: Import
# Import pandas, numpy, matplotlib

# %%
# Pista: import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
assert 'pd' in dir()
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 2: Load stock
# https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv

# %%
# Pista: pd.read_csv()
apple = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv")

# %%
assert apple.shape[0] > 0
print('✓ Cargado')
# Out:
# ✓ Cargado

# %% [markdown]
# ### Ejercicio 3: Check types
# Check column types

# %%
# Pista: .dtypes
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %%
print('OK')
print('✓ OK')
# Out:
# OK
# ✓ OK

# %% [markdown]
# ### Ejercicio 4: To datetime
# Convert Date to datetime

# %%
# Pista: pd.to_datetime(apple['Date'])
apple['Date'] = pd.to_datetime(apple['Date'])

# %%
assert apple_dt is not None
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 5: Set index
# Set Date as index

# %%
# Pista: .set_index('Date')
apple_idx = apple.set_index('Date')

# %%
assert apple_idx.index.name == 'Date'
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 6: Sort index
# Sort by date ascending

# %%
# Pista: .sort_index()
apple_sorted = apple_idx.sort_index()

# %%
assert apple_sorted is not None
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 7: Check dups
# Check duplicate dates

# %%
# Pista: .duplicated().any()
has_dup = apple_idx.index.duplicated().any()

# %%
assert isinstance(has_dup, (bool, np.bool_))
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 8: Resample month
# Last business day of month

# %%
# Pista: .resample('BM').last()
monthly = apple_idx.resample('BM').last()
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_13244\615280972.py:2: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   monthly = apple_idx.resample('BM').last()

# %%
assert monthly is not None
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 9: Date diff
# Days between first and last

# %%
# Pista: (apple_idx.index[-1] - apple_idx.index[0]).days
days_diff = (apple_idx.index[-1] - apple_idx.index[0]).days

# %%
assert isinstance(days_diff, (int, np.integer))
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 10: Months count
# Number of months

# %%
# Pista: len(apple_idx.resample('M'))
months = len(apple_idx.resample('M'))
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_13244\852175876.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   months = len(apple_idx.resample('M'))

# %%
assert months > 0
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 11: Plot close
# Plot closing price

# %%
# Pista: apple_idx['Adj Close'].plot(figsize=(13.5, 9))
plot_close = apple_idx['Adj Close'].plot(figsize=(13.5, 9))

# %%
assert plot_close is not None
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 12: Rolling mean
# 30-day rolling mean

# %%
# Pista: .rolling(window=30).mean()
rolling = apple_idx['Adj Close'].rolling(window=30).mean()

# %%
assert rolling is not None
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 13: Year group
# Group by year

# %%
# Pista: .groupby(apple_idx.index.year).mean()
yearly = apple_idx.groupby(apple_idx.index.year).mean()

# %%
assert yearly is not None
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 14: Volatility
# Daily returns

# %%
# Pista: .pct_change()
returns = apple_idx['Adj Close'].pct_change()

# %%
assert returns is not None
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ### Ejercicio 15: Cumulative
# Cumulative returns

# %%
# Pista: (1 + .pct_change()).cumprod() - 1
cum_ret = (1 + apple_idx['Adj Close'].pct_change()).cumprod() - 1

# %%
assert cum_ret is not None
print('✓ OK')
# Out:
# ✓ OK

# %% [markdown]
# ## ¡Completado! 🎉
